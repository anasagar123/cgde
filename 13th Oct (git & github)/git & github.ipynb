# %% [markdown]
# # **git**

# %%
# git is nothing its a basically tracking changes in the computer files.
# git is Open Source.
# git is also called s/w configuration management.
# git is basically distributed version control System(DVCS).

# %% [markdown]
# ![Screenshot 2024-12-10 142327.png](attachment:b824a22f-09c1-4f1a-b89e-cb43483fa066.png)

# %%
# git status (check status)
# git init (initialization)
# git --version
# git config --global --list (check username, user email)
# git config --global user.name (create or change username)
# git config --global user.email (create or change useremail)

# git add .
# git commit -m "version"

# %%
                        ### Login Github Account   ###
# go under the repository(MLOps)-----> Setting -----> SSH and GPG keys ----> open (Check out our guide to connecting to GitHub using SSH keys or troubleshoot common SSH problems) -------->
# open(Generating a new SSH key and adding it to the ssh-agent) -----> paste in git bash (ssh-keygen -t ed25519 -C "anandsagar321654@gmail.com")-----> open(Add the SSH public key to your 
# account on GitHub. For more information, see "Adding a new SSH key to your GitHub account.") ------> paste in git bash (clip < ~/.ssh/id_ed25519.pub) (copy ssh key and save ssh keys under the SSH and GPG keys)
# -------> paste in git bash (git push -u origin master) (if "git push -u origin master" will not work then before 
# run "git push -u origin master", we have to run "git remote add origin git@github.com:anasagar123/MLOps.git(MLOps is repository)" then, run "git push -u origin master"

# %%
# git pull origin master
