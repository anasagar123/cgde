# %% [markdown]
# **16th SEP(8:30PM to 10:30PM)(2023)**

# %% [markdown]
# ![Screenshot (75).png](data:image/png;base64,...)

# %%
              ## what is market risk?
#----> Market risk is the risk that arises from movements in stock prices, interest rates, exchange rates, and commodity prices.
# ----> Market risk is the what is the factor that effect the overall Performance of Investments in the financial markets.

# %%
        ## What is Algorithm Trading?

# %% [markdown]
# ![Screenshot (76).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (77).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (78).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (79).png](data:image/png;base64,...)

# %%
            ## Optimization Problem :-

# %% [markdown]
# ![Screenshot (80).png](data:image/png;base64,...)

# %% [markdown]
# **17th SEP(8:30PM to 10:30PM)(2023)**

# %%
      ## Portfolio optimization :
#---> we have to invest money, 10 lakh fund there, 10 stock is there, which stock you will invest how much amount will invest, how we will do it,
#        for that we are using optimization Technique.

       # (1) Matrix Multiplication

# %% [markdown]
# ![Screenshot (81).png](data:image/png;base64,...)

# %%
 # (2) var(x) - variance of x
#       covar(x,y) - covariance of x y

# var(x) = sum(x-xbar)(x-xbar)/n
# covar(x,y) = sum(x-xbar)(y-ybar)/n

# %%
# Sx - standard deviation of x
# Sy - standard deviation of y

# %% [markdown]
# ![Screenshot (82).png](data:image/png;base64,...)

# %%
   # (3) var-covar

# %% [markdown]
# ![Screenshot (83).png](data:image/png;base64,...)
