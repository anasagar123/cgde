# %% [markdown]
# # **Stabble Diffusion**

# %% [markdown]
# ###  https://arxiv.org/pdf/2006.11239
#
# ###  https://arxiv.org/pdf/2105.05233

# %%
#---> Stabble Diffusion is developed by the Stability AI.
#---> its a SOTA(State of the Art) Model. 
#---> its a very costly.
#---> Stabble diffusion means we have to give the input as a text and we ahve to build the model and we will get the output in image format.
#---> its a text to image.

# %% [markdown]
# ![Screenshot 2024-12-01 220846.png](attachment:9c1b3c0f-2833-47c3-8e85-ae38134b3556.png)

# %%
#---> Open AI released DALLE-2
#---> DALLE_2 is doing the same thing,we will write the text and will get the image.

# %%
# we have to write the prompt and pass the stabble diffusion then it will generate the result.

# %%
# Prompt Engineering with stable Diffusion 

# Rule (i) - Subject(A noun eg, a dog, a cat etc)
# rule (ii) - description of subject - A verb (like a dog playing a piyano)
# style (iii) - 3d,4d,i want to make scatch, etc
# Instrumentation (iv) - how they are clicking the picture like camera name,pixel size etc
# quality (v) - hd,sd,super quality etc

# %%
# For practice we can use huggingFace
