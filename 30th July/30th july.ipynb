# %% [markdown]
# # PERCEPTRON

# %%
# Perceptron means only one hidden layer there.

# %% [markdown]
# ![Screenshot%202024-04-17%20135206.png](attachment:Screenshot%202024-04-17%20135206.png)

# %%
# N number of hidden layer is nothing but multilayer perceptron(MLP)
# Multilayer perceptron is nothing but DNN(deep neural network) because n number of neurons is there

# %%
# in fig we can see that each hidden layer, multiple neurons is there and connected with each other
# hidden layer 1 = 4 neurons
# hidden layer 2= 3
# hidden layer 3= 2
# hidden layer 4=1

# how much weight calculated : 4*4+4*3+3*2+2*1 = 16+12+6+2 = 36
# how many bias : 4+3+2+1 = 10
# Total Parameter = weight + Bias = 36+10 = 46

# %% [markdown]
# ![Screenshot%202024-04-17%20142928.png](attachment:Screenshot%202024-04-17%20142928.png)

# %%
# Q. why should we care about MLP?

# %% [markdown]
# ![Screenshot%202024-04-17%20173728.png](attachment:Screenshot%202024-04-17%20173728.png)

# %%
# Notation

# I/p - input
# HL1 - hidden layer 1 
# HL2 - hidden layer 2
# O/p - output

# Oij  - O(output)
#      - i(layer)
#      - j(index)

# %%
# how many Bias there = total number of neurons

# %% [markdown]
# ![Screenshot%202024-04-17%20220044.png](attachment:Screenshot%202024-04-17%20220044.png)

# %% [markdown]
# ![Screenshot%202024-04-17%20222112.png](attachment:Screenshot%202024-04-17%20222112.png)

# %% [markdown]
# ![Screenshot%202024-04-17%20220245.png](attachment:Screenshot%202024-04-17%20220245.png)

# %%
# Xij - i(point)
#        j(Feature)

# %% [markdown]
# ![Screenshot%202024-04-17%20221800.png](attachment:Screenshot%202024-04-17%20221800.png)

# %% [markdown]
# # BACKPROPOGATION

# %%
# Entire Deep Learning Neural Network Depend upon Backprogation method.
#      Backprogation method
#        (i) Chain Rule
#        (ii) Memoization
        
# Backprogation method will do update the weight(slope) value & Bias

# %%
# Training on multilayer perceptron : chain Rule
# Algorithm name is Backpropogation

# %%
################   Rule 1:  Define Loss Function   ##################

#    Loss is nothing but its error

#  yi^ - y i hat is hidden layer

# %% [markdown]
# ![Screenshot%202024-04-17%20225647.png](attachment:Screenshot%202024-04-17%20225647.png)

# %% [markdown]
# ![Screenshot%202024-04-17%20230537.png](attachment:Screenshot%202024-04-17%20230537.png)

# %%
# why use Backpropogation?
# ---> because i can choose the right weight and my loss value is closer to zero(0) or exactly zero(0).

# %% [markdown]
# ![Screenshot%202024-04-17%20225931.png](attachment:Screenshot%202024-04-17%20225931.png)

# %%
################## Rule 2 : Optimization - Reduce the loss  ################

# For optimization I have to minimize the weight value and bias. 

# how we will optimize, then concept is coming Gradient descent.

# %%
################ Rule 3 : Gradient descent method  ########################

# In Ml we use only three gradient descent method(Batch gradient 
#   descent/vanilla gd,Stochastic gradient descent,mini batch gradient descent)

# %%
    ##  How gradient descent is working in deep learning   ##
    
# (a) Initialized weight : 
# (b) Update the weight
# (c) Perform updates till the convergence
#    NOTE : convergence means the new weight & old weight are very 
#           close to each other and no changes happen after doing multiple iteration.

# %% [markdown]
# ![Screenshot%202024-04-18%20231801.png](attachment:Screenshot%202024-04-18%20231801.png)
