# %% [markdown]
# # **CLASS 1(30th Sep 2024)(GENAI,OpenAI,HuggingFace,Langchain,Prompt,PromptEngineering)**

# %%
# What is GenAI?
# Examples of AI Apllication
# End-to-End Application
# Focus GENAI Part

# Prompt Engineering + API (for text)
# RAG + LangChain (for text)
# Fine Tuning      (for text)
# Stable Diffusion  (for image)
# LLMOPS

# %%
# GENAI :-
# ---> we will give input data(input data means sequence) and use GenAi model to generate new text data(text data is also sequence).
# ---> Sequence is nothing but Prompt.
# GenAi is for text(Prompt Engineering+API,RAG+LangChain,Fine Tuning) and image(Stable Diffusion) data.

# %%
# Prompt is nothing but its a input data.

# %%
# OPEN AI is a company.they build chat gpt.
# Hugging Face is a Company.its a open source.
# LangChain is also a company.

# %%
  ## Q. How do you build a LLM(Large Language Model)?
# ---> Huge amount of Language/Text data is required.on the top of we have to build a 
#      Algorithm(Encoder,Decoder type of Algorithm with Attention Mechanism).This is nothing its a LLM model.

# ---> LLM model is nothing its already the data which is trained with the other dataset.we can give the new data they can can give the other data.

# %%
# To Build LLM Model?
# ---> Better Approach to Build LLM Model,Use already existing LLM's which are pre-trained on Language Task.
# ---> Thats why we use them already pre-trained model.

# %%
  ## Three Major Approach :
# (i) Prompt Engineering
# (ii) RAG Approach
# (iii) Fine Tuning

# %%
 ## How to bulid a Machine Translation,Text Summerization and question answer chatbot?
 #---> Step 1 : Identify a Good Large Language Model(GPT from OpenAI,Gemini from google,Lama from meta these are the good model)
 #---> Step 2 : Experiment with the following data(Prompt Engineering,RAG,Fine Tunning)

# %%
# Design better input to get good quality result for a LLM.

# %%
# Prompt is nothing but input data in LLM.

# %% [markdown]
# **Prompt Engineering**

# %%
# how nicely we are writing the input,How nicely we are desigining.that is called Prompt Engineering.
# Prompt is input data and how we are designing it,how we are providing the data in Large Language 
#  Model,which can get desire result or to improve the programming language.that is what is called Prompt Engineering.

# %%
              #### WHAT IS PROMPT?
# ---> Input to an LLM

                #### What is Prompt Engineering?
#  ---> Prompt engineering/Designing is about providing input to the LLMs which can help us desired results & improve the 
#        Language model performance. 


                #### Approach for Prompt Engineering :
# Step(i) write the clear Instruction
# step(ii) Few/Zero shot Learning
# step(iii) Output Structure
# step(iv)  Prompt Personas.
# step(v)   give the model time to think 


              #### Two More prompt engineering Technique :
# (i) COT - Chain of thought(it is nothing time to think),This is also part of Prompt Engineering. 
# (ii) ReACT - This part will cover in Langchain.

# %%
   ## How to generate Propmt Engineering :-
# ---> Step(i) write the clear Instruction
# ---> step(ii) Few/Zero shot Learning
# ---> step(iii) Output Structure
# ---> step(iv)  Prompt Personas.
# ---> step(v)   give the model time to think

# %%
# ---> Step(i) Write the clear Instruction - clear instruction means proper manner which through we will get Correct Output.
# ---> Step(ii) Few/Zero Shot Learning -  Providing a small number of examples to train an AI model to perform a task
# ---> Step(iii) Output Structure - using a structure format can help ensure consistency in the output and reduce the risk of errors or inconsistencies.

# %% [markdown]
# ![Screenshot 2024-10-15 001435.png](data:image/png;base64,...)

# %%
# ---> step(iv)  Prompt Personas- Personas means Personality. 
#                                - Here i am giving some behaviour(education counsellor,rude counsellor,excitable counsellor)

# %% [markdown]
# ![Screenshot 2024-10-15 003123.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-15 003219.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-15 003416.png](data:image/png;base64,...)

# %%
# ---> step(v) LLMs are zero-shot Reasoners(i.e. give the model time to think) - if we giving input like logical reasoning and some other difficult thing then we have to give time to model to think.

# %%
# COT - Chain of thought(it is nothing time to think),This is also part of Prompt Engineering.

# %% [markdown]
# # **CLASS 2(1st Oct 2024)(Limitation in LLM)**

# %%
# if i will build GENAI model,huge amount of data will be required.
# GPT model trained the data till 2022 only.

# %%
        ### First Problem : Limited Knowledge
# They have Limited knowledge,gpt 3.5 model trained till jan 2022 only.after that any new project or else came they dont have a know knowledge.

# %%
            ### Second Problem : Hallucination
# Hallucination means what we can see that is not true.
# Hallucination refers to the occurence where AI model generates fake or imagined data that resemble real world data but is not actually based on any real observations.
# chatgpt dont have a knowledge but they pretend that i have.
# Like if i will search on chatgpt who is anand sagar at radharaman. chatgpt will give the response but we cant say that is correct or not because they dont know about anand sagar.

# %%
                #### RAG + Langchain
# GENAI is trained with open source data, when we have a confidential data that is not publicaly available, and 
#  there if we want to build the model(question answer,summerization,machine learning translation etc), we can do by the help of RAG+Langchain.

# %%
   ## Example the rewrite the email.

# Rewrite the email written below.it should address a profession audience who is enrolled in specialization course with Learnbay.

#hi,
# Certified related : Reach operation support team from Learnbay in the Team.Note-before reaching ensure you 
#  Check certificate completion message in your respective batch group (check pin message for quick access)

# %% [markdown]
# # **CLASS 3(3rd Oct 2024)(OPENAI)**

# %%
# For text Language - GPT3.5,4,40 etc
# For Image Purpose - DALLE
# For Audio to Text - Whisper

# %%
# API Key is nothing its a loker,if door is close,if we want to open the door key is required.same here in OPENAI.

# %%
# 1. Create/Login to OpenAI Account
# 2. Make sure you have credits to access the models
# 3. Create an API Key to access GPT3.5,4,4O,Whisper,DALL-E etc

# %%
# Using OpenAI's for Text Generation model's you can build application to -

# (a) Draft documents
# (b) Write computer code
# (c) Answer Question about a knowledge
# (d) Analyze text
# (e) Translate Language
# (f) Tutor in a range of subject
# (g) audio to text,text to audio,image 
# and so many thing

# %%
# Install OpenAI Package

# !pip install openai

# %%
# Importing OpenAI

# from openai import OpenAI

# %% [markdown]
# **How we will write the code**

# %%
        ## Way 1

    # very bad way of setting the key(paste key here).It expose the key and anyone can steal it. 
# OPENAI_API_KEY="API Key"
# client = OpenAI(api_key=OPENAI_API_KEY)

# %%
      ## directory

# import os
# os.getcwd()

# %%
            ## Way 2

# good way of setting the key(paste the key file).through this approach no one can steal it.

# f=open('keys/paste_text__file_here')
# OPENAI_API_KEY = f.read()
# client = OpenAI(api_key=OPENAI_API_KEY)

# %%
            ## way 3 

#!pip install python-dotenv
# from dotenv import dotenv_values
# config = dotenv_values("keys/.env")

# %%
#client.models.list() # its entry and these are the models we can utilize them like gpt3.5,4,4O etc

# gpt-3.5-turbo - Cost wise very less

# %%
      ## here we can do this thing :
# how you can generate the text
# how you can generate the image etc.

# %% [markdown]
#        ##Chat API
# Requirement Parameters
#
# (i) Model
#
# (ii) Messages - system message,user message,assistance message and tool message

# %%
# response = client.chat.completions.create(model="gpt-3.5-turbo",
#                                           message=[{"role":"user","content":"Generate 3 data science question and answer for MCQ test."}])
# response




# minimum two thing is required to build the model model and message
# content means which type of output i want
# In message two thing is there (i) role - role means user(giving the input)
#                                (ii) content - content means which type of output i want

# %%
# if we will see the response then its not looking good

# print(response.choice[0].message.content)

# %%
  ## Example with parameters - "max_tokens"

# prompt = "Give me a numbered list of all the modules one should study in data science?"

# response = client.chat.completions.create(model = "gpt-3.5-turbo",message=[{"role":"user","content":prompt}],max_tokens=100)

# print(response.choice[0].message.content)

# %%
  ## Example with parameters - "stop" and "max_token"
# stop means line by line it will stop.

# prompt = "Give me a numbered list of all the modules one should study in data science?"

# response = client.chat.completions.create(model = "gpt-3.5-turbo",message=[{"role":"user","content":prompt}],max_tokens=100,stop="10.")

# print(response.choice[0].message.content)

# %%
     ## Example with parameters - "frequency_penalty"

# frequency_penalty range between -2 to 2
# default value = 0 
# if frequency_penalty = -1, if any word is significant,then that word will come more times 
# if frequency_penalty = 1,  word will not come again and again

# prompt = "Give me a numbered list of all the modules one should study in data science?"

# response = client.chat.completions.create(model = "gpt-3.5-turbo",message=[{"role":"user","content":prompt}],max_tokens=100,frequency_penalty=-2)

# print(response.choice[0].message.content)

# %%
        ## Example with parameters - "temperature"
# temperature is kind of probability value,but it will give the scale value.
# Range is between 0 and 2
#


# prompt = "Give me a numbered list of all the modules one should study in data science?"

# response = client.chat.completions.create(model = "gpt-3.5-turbo",message=[{"role":"user","content":prompt}],max_tokens=100,temperature=2) # if temperature is more then 1,then output would be depressed.it will not give answer in a proper manner.

# print(response.choice[0].message.content)

# %%
# prompt = "Give me a numbered list of all the modules one should study in data science?"

# response = client.chat.completions.create(model = "gpt-3.5-turbo",message=[{"role":"user","content":prompt}],max_tokens=100,temperature=0.1) # if temperature is less then 1 like 0.1/0.2/0.5/0.8 etc then it will give proper output

# print(response.choice[0].message.content)

# %% [markdown]
# **Image API - DALL-E 2/3**

# %%
# response = client.images.generate(mode = "dall-e-2",
#      prompt="A digital image captured of an astronaut who is driving a school bus in a garden")

# size = "1024x1024",quality = "standard",n=1) # n means no. of image 

# image_url = response.data[0].url
# print(image_url)

# %%
# import matplotlib.pyplot as plt
# from PIL import image
# import requests

# def image_from_url(image_url):
#     img = Image.open(requests.get(image_url,stream=True).raw)
#     return img


# img = image_from_url(image_url)
# plt.imshow(img)
# plt.show()

# %% [markdown]
# # **CLASS 4 (4th Oct 2024)(Streamlit)**
